# %% [markdown]
# # 02 Benchmark Scenarios
#
# This notebook calculates predicted X-Theta relational phases for various physical regimes.
#
# > **Scientific Scope:** Micius-like and GPS-like scenarios are treated as null-regime consistency checks. The predicted X-Theta corrections are far below current experimental sensitivity and should not be interpreted as positive evidence.

# %%
from xtheta.experiments.benchmarks import run_benchmark_scenarios
import pandas as pd

print("--- X-Theta V2 Benchmark Scenarios ---")

results = run_benchmark_scenarios()
df = pd.DataFrame(results)

display(df[[
    'scenario',
    'phi_rel',
    'phi_rel_scientific',
    'S_max',
    'delta_S_from_tsirelson',
    'delta_S_scientific',
    'R_theta',
    'R_theta_scientific',
    'concurrence',
    'purity'
]])
# Out:
# --- X-Theta V2 Benchmark Scenarios ---
#        scenario       phi_rel phi_rel_scientific     S_max  \
# 0        Micius -1.908228e-11        -1.9082e-11  2.828427
# 1           GPS -1.662531e-09        -1.6625e-09  2.828427
# 2  Neutron Star  3.405123e-01         3.4051e-01  2.532680
# 3    Black Hole  5.243012e-01         5.2430e-01  2.234980
#
#    delta_S_from_tsirelson delta_S_scientific       R_theta R_theta_scientific  \
# 0            8.881784e-16         8.8818e-16  1.332268e-15         1.3323e-15
# 1            8.881784e-16         8.8818e-16  1.332268e-15         1.3323e-15
# 2            2.957470e-01         2.9575e-01  7.927657e-01         7.9277e-01
# 3            5.934466e-01         5.9345e-01  1.502431e+00         1.5024e+00
#
#    concurrence  purity
# 0     1.000000     1.0
# 1     1.000000     1.0
# 2     0.776928     1.0
# 3     0.498783     1.0

# %% [markdown]
# ## Conclusion
#
# Earth-orbit scenarios (Micius, GPS) show effectively zero predicted deviation, while extreme regimes (Neutron Star, Black Hole) show significant anisotropy.
#
# **Claim Classification:** This result is **simulation/benchmark**. It identifies the physical regimes where the X-Theta effect becomes potentially observable.
