# %%
import sys
import platform
from pathlib import Path

repo_root = Path.cwd().resolve()
for _ in range(8):
    if (repo_root / 'src').exists() and (repo_root / 'paper2').exists():
        break
    repo_root = repo_root.parent

src_path = str(repo_root / 'src')
if src_path not in sys.path:
    sys.path.insert(0, src_path)

print('Python:', sys.version.split()[0])
print('Platform:', platform.platform())
print('Repo root:', repo_root)
print('sys.path[0]:', sys.path[0])
# Out:
# Python: 3.13.5
# Platform: Windows-11-10.0.26200-SP0
# Repo root: C:\workspace\Physics\X-theta-framework
# sys.path[0]: C:\workspace\Physics\X-theta-framework\src

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib as mpl

print('numpy', np.__version__)
print('pandas', pd.__version__)
print('scipy', scipy.__version__)
print('matplotlib', mpl.__version__)

from sim.xtheta_sim import XThetaQuantumSim
print('XThetaQuantumSim import OK:', XThetaQuantumSim)
# Out:
# numpy 2.2.4
# pandas 2.3.2
# scipy 1.16.2
# matplotlib 3.10.6
# XThetaQuantumSim import OK: <class 'sim.xtheta_sim.XThetaQuantumSim'>
